# %%
from nltk import grammar

help(grammar)
# Out:
# Help on module nltk.grammar in nltk:
#
# NAME
#     nltk.grammar
#
# DESCRIPTION
#     Basic data classes for representing context free grammars.  A
#     "grammar" specifies which trees can represent the structure of a
#     given text.  Each of these trees is called a "parse tree" for the
#     text (or simply a "parse").  In a "context free" grammar, the set of
#     parse trees for any piece of a text can depend only on that piece, and
#     not on the rest of the text (i.e., the piece's context).  Context free
#     grammars are often used to find possible syntactic structures for
#     sentences.  In this context, the leaves of a parse tree are word
#     tokens; and the node values are phrasal categories, such as ``NP``
#     and ``VP``.
#
#     The ``CFG`` class is used to encode context free grammars.  Each
#     ``CFG`` consists of a start symbol and a set of productions.
#     The "start symbol" specifies the root node value for parse trees.  For example,
# ...

# %%
dir(grammar)
# Out:
# ['CFG',
#  'DependencyGrammar',
#  'DependencyProduction',
#  'FeatDict',
#  'FeatStruct',
#  'FeatStructNonterminal',
#  'FeatStructReader',
#  'FeatureGrammar',
#  'FeatureValueType',
#  'ImmutableProbabilisticMixIn',
#  'Nonterminal',
#  'PCFG',
#  'ProbabilisticDependencyGrammar',
#  'ProbabilisticProduction',
#  'Production',
#  'SLASH',
#  'TYPE',
#  '_ARROW_RE',
#  '_DISJUNCTION_RE',
#  '_PROBABILITY_RE',
#  '_READ_DG_RE',
#  '_SPLIT_DG_RE',
#  '_STANDARD_NONTERM_RE',
#  '_TERMINAL_RE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_read_cfg_production',
#  '_read_dependency_production',
#  '_read_fcfg_production',
#  '_read_pcfg_production',
#  '_read_production',
#  'cfg_demo',
#  'demo',
#  'dg_demo',
#  'fcfg_demo',
#  'induce_pcfg',
#  'invert_graph',
#  'is_nonterminal',
#  'is_terminal',
#  'nonterminals',
#  'pcfg_demo',
#  'raise_unorderable_types',
#  're',
# ...

# %%
from nltk import grammar

text = 'Your the best but their are allso  good !'

print(grammar.read_grammar(text, grammar.Nonterminal, probabilistic=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b42686036b70> in <module>
#       3 text = 'Your the best but their are allso  good !'
#       4
# ----> 5 print(grammar.read_grammar(text, grammar.Nonterminal, probabilistic=False))
#       6
#
# d:\self\natural-language-processing\venv\lib\site-packages\nltk\grammar.py in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1447             else:
#    1448                 # expand out the disjunctions on the RHS
# -> 1449                 productions += _read_production(line, nonterm_parser, probabilistic)
#    1450         except ValueError as e:
#    1451             raise ValueError("Unable to parse line %s: %s\n%s" % (linenum + 1, line, e))
#
# d:\self\natural-language-processing\venv\lib\site-packages\nltk\grammar.py in _read_production(line, nonterm_parser, probabilistic)
#    1346
# ...
